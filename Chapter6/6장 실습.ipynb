# %%
# 확률적 경사 하강법(SGD)
class SGD:
    def __init__(self, lr = 0.01):
        self.lr = lr

    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %% [markdown]
# ## 모멘텀

# %%
import sys, os
sys.path.append(os.pardir)

import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from common.optimizer import *

#최소화할 함수
def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["Momentum"] = Momentum(lr=0.1)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]

    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])

        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)


    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)

    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)

    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0

    # 그래프 그리기
    plt.subplot(1, 1, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")

plt.show()

plt.show()

# %% [markdown]
# SGD를 사용하면 지그재그. 모멘텀을 사용하니 부드럽게 공이 그릇 바닥을 구르듯 움직임. '지그재그'가 덜함.

# %% [markdown]
# ## AdaGrad
#
# 각각의 매개변수에 맞춤형 값을 만들어 줌. 매개변수에 적응적으로 학습률 조정하면서 학습 진행.

# %%
#최소화할 함수
def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["AdaGrad"] = AdaGrad(lr=1.5)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]

    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])

        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)


    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)

    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)

    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0

    # 그래프 그리기
    plt.subplot(1, 1, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")

plt.show()

# %% [markdown]
# ## ADAM
#
# 모멘텀과 AdaGrad 기법을 융합. 유용하다.

# %%
def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]

    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])

        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)


    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)

    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)

    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0

    # 그래프 그리기
    plt.subplot(1, 1, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")

plt.show()

# %% [markdown]
# ### MNIST 손글씨 데이터셋으로 4 기법 갱신 방법 비교

# %%
#제공된 소스 코드
import sys, os

import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)

        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)

    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.370636367262068
# Momentum:2.3975763376218975
# AdaGrad:2.2312018068489206
# Adam:2.1785721966163827
# ===========iteration:100===========
# SGD:1.3926766918475804
# Momentum:0.3991311156513278
# AdaGrad:0.21337763990756867
# Adam:0.38911979971396576
# ===========iteration:200===========
# SGD:0.8852291074084637
# Momentum:0.3366800389161762
# AdaGrad:0.1146335210932155
# Adam:0.2438093374367932
# ===========iteration:300===========
# SGD:0.4785093422835882
# Momentum:0.11056477465287329
# AdaGrad:0.03761556089145184
# Adam:0.07281878771264516
# ===========iteration:400===========
# SGD:0.3810394503355571
# Momentum:0.16103645833637503
# AdaGrad:0.05301218770243189
# Adam:0.08511046877180284
# ===========iteration:500===========
# SGD:0.35455842487184436
# Momentum:0.17365224786027644
# AdaGrad:0.10129343988620207
# Adam:0.13229490027962582
# ===========iteration:600===========
# SGD:0.36769599719550106
# Momentum:0.1403442735447017
# AdaGrad:0.05809576401236602
# Adam:0.08323226360144445
# ===========iteration:700===========
# SGD:0.2019501584434788
# Momentum:0.05896852897692581
# AdaGrad:0.021837845087160322
# Adam:0.02193696200426516
# ===========iteration:800===========
# SGD:0.22069198952585015
# Momentum:0.07824056849976614
# AdaGrad:0.03006584042754174
# Adam:0.03468601244098665
# ===========iteration:900===========
# SGD:0.29145748746043787
# Momentum:0.09987097663378544
# AdaGrad:0.05737855161337239
# Adam:0.05907958161082991
# ===========iteration:1000===========
# SGD:0.2991078888393848
# Momentum:0.11574785379819139
# AdaGrad:0.03612207095697561
# Adam:0.11439975119426077
# ===========iteration:1100===========
# SGD:0.29670874735508423
# Momentum:0.10313379669055092
# AdaGrad:0.04732458049857425
# Adam:0.10624888336956273
# ===========iteration:1200===========
# SGD:0.25596602781725364
# Momentum:0.1083028012585309
# AdaGrad:0.03435460743750785
# Adam:0.11216301461258936
# ===========iteration:1300===========
# SGD:0.1996441297732485
# Momentum:0.07792749864695536
# AdaGrad:0.03749043618501489
# Adam:0.02783805632003016
# ===========iteration:1400===========
# SGD:0.16423989633315525
# Momentum:0.056429825463245285
# AdaGrad:0.04601628656230901
# Adam:0.04836766474577795
# ===========iteration:1500===========
# SGD:0.23490604315744051
# Momentum:0.06635564125805102
# AdaGrad:0.04063580463664013
# Adam:0.051914374515893286
# ===========iteration:1600===========
# SGD:0.2571882480782308
# Momentum:0.08737351477835936
# AdaGrad:0.04360321898733319
# Adam:0.04802235252905909
# ===========iteration:1700===========
# SGD:0.23209968255270808
# Momentum:0.05463206107271924
# AdaGrad:0.02857419185003683
# Adam:0.040025675795713936
# ===========iteration:1800===========
# SGD:0.18279566679569584
# Momentum:0.05005622648796303
# AdaGrad:0.01937239108217435
# Adam:0.03169407703408845
# ===========iteration:1900===========
# SGD:0.24822418550578082
# Momentum:0.07228434685615591
# AdaGrad:0.020928130166669376
# Adam:0.02492108886224475

# %% [markdown]
# ## 가중치의 초깃값 설정

# %%
#가중치의 초깃값에 따라 은닉층 활성화 값들이 어떻게 변화하는지?
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)

input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 초깃값을 다양하게 바꿔가며 실험해보자！
    #w = np.random.randn(node_num, node_num) * 1
    #w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num) #Xavier 초깃값
    w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 활성화 함수도 바꿔가며 실험해보자！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# 히스토그램 그리기
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %% [markdown]
# ## MNIST 실제 데이터를 가지고 가중치의 초깃값을 주는 방법이 신경망 학습에 얼마나 영향을 주는지 보기

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)

        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)

    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.3025424571930606
# Xavier:2.300310760213968
# He:2.285433063734425
# ===========iteration:100===========
# std=0.01:2.301703004467046
# Xavier:2.2315802198845445
# He:1.3812226146014797
# ===========iteration:200===========
# std=0.01:2.3025748689949608
# Xavier:2.141117487261221
# He:0.7805863130303627
# ===========iteration:300===========
# std=0.01:2.302593583752556
# Xavier:1.8635820902443676
# He:0.5631729727278485
# ===========iteration:400===========
# std=0.01:2.302210503471232
# Xavier:1.39877996870382
# He:0.43550047212369447
# ===========iteration:500===========
# std=0.01:2.3023113819795293
# Xavier:0.9956043336692683
# He:0.3776631273893227
# ===========iteration:600===========
# std=0.01:2.2996278555272864
# Xavier:0.7149789038305177
# He:0.3453589689485167
# ===========iteration:700===========
# std=0.01:2.3029093352156913
# Xavier:0.6910997269443835
# He:0.35387679993408183
# ===========iteration:800===========
# std=0.01:2.301114555980721
# Xavier:0.5071083482740086
# He:0.28187898708380577
# ===========iteration:900===========
# std=0.01:2.3090665989074357
# Xavier:0.42802353590062536
# He:0.25784169310746385
# ===========iteration:1000===========
# std=0.01:2.301239101388904
# Xavier:0.45944762433690167
# He:0.2587833141702346
# ===========iteration:1100===========
# std=0.01:2.3007646790391227
# Xavier:0.36347696042696087
# He:0.2840058345201843
# ===========iteration:1200===========
# std=0.01:2.30279551237943
# Xavier:0.30851880735416937
# He:0.16769059940807407
# ===========iteration:1300===========
# std=0.01:2.293658674075284
# Xavier:0.3650170602880536
# He:0.3289163498370911
# ===========iteration:1400===========
# std=0.01:2.2985327992298927
# Xavier:0.40114257119168556
# He:0.3115336323807067
# ===========iteration:1500===========
# std=0.01:2.298305950835282
# Xavier:0.2253121075999085
# He:0.15749756849060914
# ===========iteration:1600===========
# std=0.01:2.2986146830057534
# Xavier:0.4356345770181731
# He:0.31509584757284353
# ===========iteration:1700===========
# std=0.01:2.3024342909141096
# Xavier:0.21189335447032887
# He:0.1732832586485994
# ===========iteration:1800===========
# std=0.01:2.306373698212126
# Xavier:0.2575259126035439
# He:0.20523159210302316
# ===========iteration:1900===========
# std=0.01:2.30242993977265
# Xavier:0.25713972487330394
# He:0.16926364388653012

# %% [markdown]
# ## 오버피팅

# %%
#오버피팅 구현
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 과대적합을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = SGD(lr=0.01)  # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# 그래프를 보면 훈련데이터에만 적응해버린 결과

# %% [markdown]
# ## 오버피팅 억제
#
# 그중 하나로 가중치 감소. 오버피팅은 가중치 매개변수의 값이 커서 발생하는 경우가 많다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 과대적합을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

weight_decay_lambda = 0.1 # 가중치 감쇠 설정 (람다는 정규화 세기를 조절하는 하이퍼파라미터)

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.08666666666666667, test acc:0.0936
# epoch:1, train acc:0.13, test acc:0.1139
# epoch:2, train acc:0.17666666666666667, test acc:0.1284
# epoch:3, train acc:0.20333333333333334, test acc:0.1465
# epoch:4, train acc:0.22333333333333333, test acc:0.1612
# epoch:5, train acc:0.24666666666666667, test acc:0.1854
# epoch:6, train acc:0.28, test acc:0.2081
# epoch:7, train acc:0.32666666666666666, test acc:0.2445
# epoch:8, train acc:0.37, test acc:0.275
# epoch:9, train acc:0.44333333333333336, test acc:0.3058
# epoch:10, train acc:0.4266666666666667, test acc:0.3147
# epoch:11, train acc:0.4766666666666667, test acc:0.3532
# epoch:12, train acc:0.5066666666666667, test acc:0.377
# epoch:13, train acc:0.5333333333333333, test acc:0.3984
# epoch:14, train acc:0.5566666666666666, test acc:0.4061
# epoch:15, train acc:0.5633333333333334, test acc:0.4224
# epoch:16, train acc:0.5866666666666667, test acc:0.4358
# epoch:17, train acc:0.6333333333333333, test acc:0.452
# epoch:18, train acc:0.63, test acc:0.4585
# epoch:19, train acc:0.6233333333333333, test acc:0.4587
# epoch:20, train acc:0.6466666666666666, test acc:0.4657
# epoch:21, train acc:0.65, test acc:0.4696
# epoch:22, train acc:0.6466666666666666, test acc:0.4736
# epoch:23, train acc:0.65, test acc:0.4771
# epoch:24, train acc:0.65, test acc:0.4847
# epoch:25, train acc:0.6466666666666666, test acc:0.4899
# epoch:26, train acc:0.6633333333333333, test acc:0.5018
# epoch:27, train acc:0.6733333333333333, test acc:0.4996
# epoch:28, train acc:0.6733333333333333, test acc:0.5019
# epoch:29, train acc:0.67, test acc:0.5146
# epoch:30, train acc:0.6733333333333333, test acc:0.514
# epoch:31, train acc:0.6833333333333333, test acc:0.5228
# epoch:32, train acc:0.7, test acc:0.5275
# epoch:33, train acc:0.7166666666666667, test acc:0.5324
# epoch:34, train acc:0.7166666666666667, test acc:0.5364
# epoch:35, train acc:0.7166666666666667, test acc:0.5448
# epoch:36, train acc:0.71, test acc:0.5481
# epoch:37, train acc:0.7333333333333333, test acc:0.558
# epoch:38, train acc:0.7433333333333333, test acc:0.5552
# epoch:39, train acc:0.76, test acc:0.5607
# epoch:40, train acc:0.78, test acc:0.573
# epoch:41, train acc:0.7766666666666666, test acc:0.5796
# epoch:42, train acc:0.7933333333333333, test acc:0.5896
# epoch:43, train acc:0.7833333333333333, test acc:0.5987
# epoch:44, train acc:0.8033333333333333, test acc:0.5888
# epoch:45, train acc:0.7966666666666666, test acc:0.5867
# epoch:46, train acc:0.7966666666666666, test acc:0.6059
# epoch:47, train acc:0.8166666666666667, test acc:0.6071
# epoch:48, train acc:0.8166666666666667, test acc:0.6163
# epoch:49, train acc:0.8166666666666667, test acc:0.6199
# epoch:50, train acc:0.81, test acc:0.6179
# epoch:51, train acc:0.8266666666666667, test acc:0.6264
# epoch:52, train acc:0.8266666666666667, test acc:0.6283
# epoch:53, train acc:0.8233333333333334, test acc:0.6177
# epoch:54, train acc:0.82, test acc:0.6227
# epoch:55, train acc:0.8133333333333334, test acc:0.6217
# epoch:56, train acc:0.82, test acc:0.6432
# epoch:57, train acc:0.83, test acc:0.6449
# epoch:58, train acc:0.8333333333333334, test acc:0.6485
# epoch:59, train acc:0.8366666666666667, test acc:0.6486
# epoch:60, train acc:0.86, test acc:0.6522
# epoch:61, train acc:0.85, test acc:0.6455
# epoch:62, train acc:0.85, test acc:0.6501
# epoch:63, train acc:0.86, test acc:0.6533
# epoch:64, train acc:0.85, test acc:0.6517
# epoch:65, train acc:0.8433333333333334, test acc:0.6488
# epoch:66, train acc:0.84, test acc:0.6613
# epoch:67, train acc:0.8466666666666667, test acc:0.6604
# epoch:68, train acc:0.8433333333333334, test acc:0.6646
# epoch:69, train acc:0.8566666666666667, test acc:0.664
# epoch:70, train acc:0.8533333333333334, test acc:0.6659
# epoch:71, train acc:0.8766666666666667, test acc:0.6751
# epoch:72, train acc:0.87, test acc:0.6728
# epoch:73, train acc:0.8633333333333333, test acc:0.6643
# epoch:74, train acc:0.8633333333333333, test acc:0.6634
# epoch:75, train acc:0.87, test acc:0.6665
# epoch:76, train acc:0.87, test acc:0.6724
# epoch:77, train acc:0.8766666666666667, test acc:0.6769
# epoch:78, train acc:0.8733333333333333, test acc:0.674
# epoch:79, train acc:0.8733333333333333, test acc:0.67
# epoch:80, train acc:0.88, test acc:0.6684
# epoch:81, train acc:0.8766666666666667, test acc:0.6825
# epoch:82, train acc:0.8766666666666667, test acc:0.6843
# epoch:83, train acc:0.8766666666666667, test acc:0.675
# epoch:84, train acc:0.8833333333333333, test acc:0.6857
# epoch:85, train acc:0.8733333333333333, test acc:0.6794
# epoch:86, train acc:0.8766666666666667, test acc:0.6825
# epoch:87, train acc:0.87, test acc:0.6828
# epoch:88, train acc:0.8733333333333333, test acc:0.6933
# epoch:89, train acc:0.8833333333333333, test acc:0.6856
# epoch:90, train acc:0.8766666666666667, test acc:0.6871
# epoch:91, train acc:0.88, test acc:0.6872
# epoch:92, train acc:0.8833333333333333, test acc:0.6795
# epoch:93, train acc:0.8833333333333333, test acc:0.683
# epoch:94, train acc:0.89, test acc:0.6954
# epoch:95, train acc:0.8833333333333333, test acc:0.6948
# epoch:96, train acc:0.8833333333333333, test acc:0.6871
# epoch:97, train acc:0.89, test acc:0.6942
# epoch:98, train acc:0.8866666666666667, test acc:0.7005
# epoch:99, train acc:0.8933333333333333, test acc:0.7038
# epoch:100, train acc:0.89, test acc:0.6939
# epoch:101, train acc:0.89, test acc:0.7007
# epoch:102, train acc:0.89, test acc:0.7048
# epoch:103, train acc:0.8966666666666666, test acc:0.7061
# epoch:104, train acc:0.8966666666666666, test acc:0.7076
# epoch:105, train acc:0.8933333333333333, test acc:0.7091
# epoch:106, train acc:0.8866666666666667, test acc:0.7047
# epoch:107, train acc:0.9, test acc:0.7038
# epoch:108, train acc:0.89, test acc:0.7102
# epoch:109, train acc:0.9033333333333333, test acc:0.7088
# epoch:110, train acc:0.9066666666666666, test acc:0.7107
# epoch:111, train acc:0.8966666666666666, test acc:0.702
# epoch:112, train acc:0.8833333333333333, test acc:0.6988
# epoch:113, train acc:0.89, test acc:0.7055
# epoch:114, train acc:0.8933333333333333, test acc:0.7038
# epoch:115, train acc:0.8966666666666666, test acc:0.7019
# epoch:116, train acc:0.8966666666666666, test acc:0.7084
# epoch:117, train acc:0.9033333333333333, test acc:0.7093
# epoch:118, train acc:0.8966666666666666, test acc:0.7126
# epoch:119, train acc:0.9, test acc:0.7152
# epoch:120, train acc:0.8966666666666666, test acc:0.715
# epoch:121, train acc:0.8933333333333333, test acc:0.714
# epoch:122, train acc:0.8966666666666666, test acc:0.7094
# epoch:123, train acc:0.8966666666666666, test acc:0.716
# epoch:124, train acc:0.8933333333333333, test acc:0.7026
# epoch:125, train acc:0.8933333333333333, test acc:0.7041
# epoch:126, train acc:0.9066666666666666, test acc:0.7181
# epoch:127, train acc:0.9066666666666666, test acc:0.721
# epoch:128, train acc:0.91, test acc:0.7154
# epoch:129, train acc:0.9, test acc:0.7209
# epoch:130, train acc:0.91, test acc:0.7218
# epoch:131, train acc:0.9, test acc:0.7197
# epoch:132, train acc:0.8933333333333333, test acc:0.7219
# epoch:133, train acc:0.9, test acc:0.7199
# epoch:134, train acc:0.9, test acc:0.7188
# epoch:135, train acc:0.9066666666666666, test acc:0.7109
# epoch:136, train acc:0.9, test acc:0.7174
# epoch:137, train acc:0.9066666666666666, test acc:0.7169
# epoch:138, train acc:0.9033333333333333, test acc:0.7194
# epoch:139, train acc:0.91, test acc:0.7192
# epoch:140, train acc:0.91, test acc:0.7258
# epoch:141, train acc:0.9133333333333333, test acc:0.719
# epoch:142, train acc:0.9133333333333333, test acc:0.7191
# epoch:143, train acc:0.91, test acc:0.7277
# epoch:144, train acc:0.9033333333333333, test acc:0.7222
# epoch:145, train acc:0.9166666666666666, test acc:0.7227
# epoch:146, train acc:0.91, test acc:0.7237
# epoch:147, train acc:0.9133333333333333, test acc:0.7252
# epoch:148, train acc:0.9133333333333333, test acc:0.7228
# epoch:149, train acc:0.9166666666666666, test acc:0.7266
# epoch:150, train acc:0.9133333333333333, test acc:0.7261
# epoch:151, train acc:0.91, test acc:0.7217
# epoch:152, train acc:0.9133333333333333, test acc:0.7274
# epoch:153, train acc:0.9166666666666666, test acc:0.7246
# epoch:154, train acc:0.91, test acc:0.724
# epoch:155, train acc:0.9, test acc:0.7281
# epoch:156, train acc:0.9066666666666666, test acc:0.7235
# epoch:157, train acc:0.91, test acc:0.7298
# epoch:158, train acc:0.9066666666666666, test acc:0.7252
# epoch:159, train acc:0.9066666666666666, test acc:0.7271
# epoch:160, train acc:0.9066666666666666, test acc:0.7266
# epoch:161, train acc:0.91, test acc:0.7231
# epoch:162, train acc:0.91, test acc:0.7194
# epoch:163, train acc:0.9166666666666666, test acc:0.7285
# epoch:164, train acc:0.91, test acc:0.7178
# epoch:165, train acc:0.9066666666666666, test acc:0.7178
# epoch:166, train acc:0.91, test acc:0.7292
# epoch:167, train acc:0.9066666666666666, test acc:0.7281
# epoch:168, train acc:0.9066666666666666, test acc:0.7207
# epoch:169, train acc:0.91, test acc:0.7274
# epoch:170, train acc:0.9133333333333333, test acc:0.7329
# epoch:171, train acc:0.91, test acc:0.7302
# epoch:172, train acc:0.91, test acc:0.7263
# epoch:173, train acc:0.9066666666666666, test acc:0.7239
# epoch:174, train acc:0.91, test acc:0.7235
# epoch:175, train acc:0.91, test acc:0.7273
# epoch:176, train acc:0.9133333333333333, test acc:0.7268
# epoch:177, train acc:0.9033333333333333, test acc:0.7266
# epoch:178, train acc:0.91, test acc:0.7317
# epoch:179, train acc:0.91, test acc:0.7308
# epoch:180, train acc:0.9066666666666666, test acc:0.7248
# epoch:181, train acc:0.9066666666666666, test acc:0.7262
# epoch:182, train acc:0.9, test acc:0.719
# epoch:183, train acc:0.8966666666666666, test acc:0.7227
# epoch:184, train acc:0.9033333333333333, test acc:0.7252
# epoch:185, train acc:0.9066666666666666, test acc:0.7188
# epoch:186, train acc:0.9033333333333333, test acc:0.7235
# epoch:187, train acc:0.9066666666666666, test acc:0.7317
# epoch:188, train acc:0.9066666666666666, test acc:0.7287
# epoch:189, train acc:0.9033333333333333, test acc:0.7293
# epoch:190, train acc:0.9066666666666666, test acc:0.7241
# epoch:191, train acc:0.9066666666666666, test acc:0.7288
# epoch:192, train acc:0.9133333333333333, test acc:0.7348
# epoch:193, train acc:0.9033333333333333, test acc:0.7267
# epoch:194, train acc:0.9033333333333333, test acc:0.7281
# epoch:195, train acc:0.91, test acc:0.733
# epoch:196, train acc:0.91, test acc:0.7342
# epoch:197, train acc:0.91, test acc:0.7354
# epoch:198, train acc:0.91, test acc:0.7316
# epoch:199, train acc:0.91, test acc:0.7318
# epoch:200, train acc:0.91, test acc:0.7244

# %% [markdown]
# 또 다른 방법으로는 드롭아웃 기법. 뉴런을 임의로 삭제하면서 학습하는 방법.

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비율 설정 ========================
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.301276864842365
# === epoch:1, train acc:0.06666666666666667, test acc:0.0882 ===
# train loss:2.307446211351123
# train loss:2.305669397725475
# train loss:2.3141997521851803
# === epoch:2, train acc:0.07, test acc:0.0895 ===
# train loss:2.2996268979798358
# train loss:2.291694397603294
# train loss:2.298090093026695
# === epoch:3, train acc:0.07333333333333333, test acc:0.0921 ===
# train loss:2.305197155734987
# train loss:2.3052241498912354
# train loss:2.2956926649262845
# === epoch:4, train acc:0.07666666666666666, test acc:0.093 ===
# train loss:2.3044852230924
# train loss:2.296208551985925
# train loss:2.292733619162969
# === epoch:5, train acc:0.09, test acc:0.0965 ===
# train loss:2.2917328889393658
# train loss:2.3048791609457164
# train loss:2.3011711552697345
# === epoch:6, train acc:0.10333333333333333, test acc:0.0992 ===
# train loss:2.2834259948268754
# train loss:2.294384408408112
# train loss:2.296764076641667
# === epoch:7, train acc:0.10666666666666667, test acc:0.0998 ===
# train loss:2.281932428165931
# train loss:2.2972269843750444
# train loss:2.294556191662268
# === epoch:8, train acc:0.11, test acc:0.1009 ===
# train loss:2.2827054451278666
# train loss:2.285205465504229
# train loss:2.295404295037821
# === epoch:9, train acc:0.11666666666666667, test acc:0.1014 ===
# train loss:2.289548924036005
# train loss:2.293487236980092
# train loss:2.2889488882742386
# === epoch:10, train acc:0.11, test acc:0.1023 ===
# train loss:2.2867412719137232
# train loss:2.295016223574164
# train loss:2.2949756104961527
# === epoch:11, train acc:0.11333333333333333, test acc:0.105 ===
# train loss:2.2904565584249412
# train loss:2.284787619956931
# train loss:2.2849520969519177
# === epoch:12, train acc:0.12666666666666668, test acc:0.1061 ===
# train loss:2.2991766829887625
# train loss:2.282990113242698
# train loss:2.293786992288414
# === epoch:13, train acc:0.12, test acc:0.1072 ===
# train loss:2.280947637283579
# train loss:2.291997271250443
# train loss:2.28675648015666
# === epoch:14, train acc:0.12666666666666668, test acc:0.1093 ===
# train loss:2.291678791826813
# train loss:2.295606174029199
# train loss:2.2841685899060855
# === epoch:15, train acc:0.12666666666666668, test acc:0.1098 ===
# train loss:2.280708939478497
# train loss:2.298278383099702
# train loss:2.287895584298503
# === epoch:16, train acc:0.13333333333333333, test acc:0.1122 ===
# train loss:2.2874681306186373
# train loss:2.281089523791032
# train loss:2.2915392589843933
# === epoch:17, train acc:0.14333333333333334, test acc:0.1143 ===
# train loss:2.309231484765349
# train loss:2.2882372873581076
# train loss:2.2767125204666936
# === epoch:18, train acc:0.15333333333333332, test acc:0.115 ===
# train loss:2.288513136203633
# train loss:2.2839347314889706
# train loss:2.2856405631910954
# === epoch:19, train acc:0.15666666666666668, test acc:0.1197 ===
# train loss:2.2828645027100087
# train loss:2.2929364849506384
# train loss:2.284377179566914
# === epoch:20, train acc:0.16, test acc:0.1203 ===
# train loss:2.28296358634754
# train loss:2.2784594427050204
# train loss:2.2807361239978197
# === epoch:21, train acc:0.15666666666666668, test acc:0.1217 ===
# train loss:2.2752138653126424
# train loss:2.273144834136331
# train loss:2.284204465486454
# === epoch:22, train acc:0.15333333333333332, test acc:0.1249 ===
# train loss:2.28411324781199
# train loss:2.280958959746586
# train loss:2.2852103438240063
# === epoch:23, train acc:0.16, test acc:0.1269 ===
# train loss:2.277627157310657
# train loss:2.2692016081426623
# train loss:2.287740314349162
# === epoch:24, train acc:0.16333333333333333, test acc:0.1298 ===
# train loss:2.274883975541872
# train loss:2.2803197710605834
# train loss:2.2695900678154164
# === epoch:25, train acc:0.16333333333333333, test acc:0.1309 ===
# train loss:2.280770343881711
# train loss:2.284395344775044
# train loss:2.285311275899373
# === epoch:26, train acc:0.16666666666666666, test acc:0.1317 ===
# train loss:2.2755118622405237
# train loss:2.264854150368758
# train loss:2.2598522293830148
# === epoch:27, train acc:0.16666666666666666, test acc:0.1329 ===
# train loss:2.273730276785613
# train loss:2.2873626921099883
# train loss:2.2704830560448457
# === epoch:28, train acc:0.17, test acc:0.1338 ===
# train loss:2.2767712473602937
# train loss:2.2805585504576036
# train loss:2.2677737354255654
# === epoch:29, train acc:0.18, test acc:0.1378 ===
# train loss:2.280565482034292
# train loss:2.2841975929107954
# train loss:2.269600695284849
# === epoch:30, train acc:0.17666666666666667, test acc:0.1449 ===
# train loss:2.27515724351404
# train loss:2.287434316522683
# train loss:2.268314862982351
# === epoch:31, train acc:0.17666666666666667, test acc:0.1457 ===
# train loss:2.2698581043415134
# train loss:2.2704628958927704
# train loss:2.2663298852669693
# === epoch:32, train acc:0.17666666666666667, test acc:0.1438 ===
# train loss:2.2596139128856536
# train loss:2.2553540107577423
# train loss:2.2531949858641482
# === epoch:33, train acc:0.18, test acc:0.1442 ===
# train loss:2.266063321770274
# train loss:2.261424735767433
# train loss:2.279518446366529
# === epoch:34, train acc:0.18333333333333332, test acc:0.1456 ===
# train loss:2.264017116230747
# train loss:2.2631083773749943
# train loss:2.2689844109344253
# === epoch:35, train acc:0.18, test acc:0.1478 ===
# train loss:2.2562761862959446
# train loss:2.2658145365146702
# train loss:2.253563038959572
# === epoch:36, train acc:0.18, test acc:0.1465 ===
# train loss:2.2734950898818096
# train loss:2.2677257043092665
# train loss:2.2579112954388325
# === epoch:37, train acc:0.2, test acc:0.1518 ===
# train loss:2.27971227972065
# train loss:2.262710457531965
# train loss:2.2811692346454184
# === epoch:38, train acc:0.2, test acc:0.1572 ===
# train loss:2.2760879628970336
# train loss:2.2699883990193914
# train loss:2.2662021510395913
# === epoch:39, train acc:0.20666666666666667, test acc:0.1562 ===
# train loss:2.2584988525659573
# train loss:2.2708066535920057
# train loss:2.2671701624965683
# === epoch:40, train acc:0.20666666666666667, test acc:0.1525 ===
# train loss:2.275982717265502
# train loss:2.252005569567237
# train loss:2.253106066172708
# === epoch:41, train acc:0.20666666666666667, test acc:0.1519 ===
# train loss:2.265610942205889
# train loss:2.251682509534998
# train loss:2.2446409200583988
# === epoch:42, train acc:0.2, test acc:0.1555 ===
# train loss:2.2594482155555253
# train loss:2.256958291504686
# train loss:2.2582308037810237
# === epoch:43, train acc:0.2, test acc:0.1574 ===
# train loss:2.265907828084933
# train loss:2.2459096956343174
# train loss:2.2640243453695974
# === epoch:44, train acc:0.19666666666666666, test acc:0.1607 ===
# train loss:2.258066453270459
# train loss:2.2648707779256005
# train loss:2.2399115087927903
# === epoch:45, train acc:0.19666666666666666, test acc:0.1643 ===
# train loss:2.263614682896494
# train loss:2.269589878761148
# train loss:2.2497710580871257
# === epoch:46, train acc:0.20666666666666667, test acc:0.1687 ===
# train loss:2.259306089103279
# train loss:2.2605516820964477
# train loss:2.2539527393998324
# === epoch:47, train acc:0.20666666666666667, test acc:0.171 ===
# train loss:2.2603688050032265
# train loss:2.253187013214473
# train loss:2.242920262944495
# === epoch:48, train acc:0.21666666666666667, test acc:0.1751 ===
# train loss:2.2652728738118566
# train loss:2.2461335778985188
# train loss:2.261757632556984
# === epoch:49, train acc:0.21666666666666667, test acc:0.1793 ===
# train loss:2.248770921606069
# train loss:2.2281661462890407
# train loss:2.2474069080234873
# === epoch:50, train acc:0.23, test acc:0.1861 ===
# train loss:2.247556998558051
# train loss:2.2253532286573248
# train loss:2.265001945159463
# === epoch:51, train acc:0.24666666666666667, test acc:0.1928 ===
# train loss:2.2648867388119074
# train loss:2.2496662554000677
# train loss:2.2542339940642524
# === epoch:52, train acc:0.24333333333333335, test acc:0.1939 ===
# train loss:2.2532582386164823
# train loss:2.2324694327172283
# train loss:2.2783481432838273
# === epoch:53, train acc:0.24333333333333335, test acc:0.1967 ===
# train loss:2.2312229592865442
# train loss:2.2405374416736366
# train loss:2.2482814534667743
# === epoch:54, train acc:0.23666666666666666, test acc:0.1939 ===
# train loss:2.2352216219226535
# train loss:2.2489279087205687
# train loss:2.240172611558592
# === epoch:55, train acc:0.24, test acc:0.1961 ===
# train loss:2.2557561504214196
# train loss:2.2310823141479856
# train loss:2.245876682705122
# === epoch:56, train acc:0.23666666666666666, test acc:0.197 ===
# train loss:2.236292252612168
# train loss:2.2578266357325067
# train loss:2.271560415180007
# === epoch:57, train acc:0.23333333333333334, test acc:0.1958 ===
# train loss:2.240091852271945
# train loss:2.2466511967392706
# train loss:2.233445991006362
# === epoch:58, train acc:0.23333333333333334, test acc:0.1947 ===
# train loss:2.249367630304781
# train loss:2.2450819151532455
# train loss:2.2182877595560897
# === epoch:59, train acc:0.23666666666666666, test acc:0.1965 ===
# train loss:2.2587424905771094
# train loss:2.233507469184444
# train loss:2.239745952948592
# === epoch:60, train acc:0.24, test acc:0.1984 ===
# train loss:2.2367433396509036
# train loss:2.254086472858004
# train loss:2.2303176571347225
# === epoch:61, train acc:0.24333333333333335, test acc:0.2037 ===
# train loss:2.251549355821921
# train loss:2.240334764861158
# train loss:2.2336117809239786
# === epoch:62, train acc:0.25, test acc:0.2096 ===
# train loss:2.2468398742315006
# train loss:2.2338298459979393
# train loss:2.2350338114799237
# === epoch:63, train acc:0.25333333333333335, test acc:0.2087 ===
# train loss:2.235570041677346
# train loss:2.2311790831801757
# train loss:2.2386284833971195
# === epoch:64, train acc:0.25, test acc:0.2042 ===
# train loss:2.236613082975647
# train loss:2.2049868510609794
# train loss:2.2562540339591814
# === epoch:65, train acc:0.25333333333333335, test acc:0.2073 ===
# train loss:2.218613339145601
# train loss:2.249579190821661
# train loss:2.2357938180797414
# === epoch:66, train acc:0.27, test acc:0.2185 ===
# train loss:2.245044833506405
# train loss:2.207780086456673
# train loss:2.2282708723447295
# === epoch:67, train acc:0.2733333333333333, test acc:0.2224 ===
# train loss:2.207842016210877
# train loss:2.2381104654045263
# train loss:2.2510556261058343
# === epoch:68, train acc:0.2833333333333333, test acc:0.2221 ===
# train loss:2.2222702120354842
# train loss:2.2326617683888004
# train loss:2.207642797934736
# === epoch:69, train acc:0.28, test acc:0.2262 ===
# train loss:2.226036132309788
# train loss:2.2294765455480756
# train loss:2.2178972041503453
# === epoch:70, train acc:0.28, test acc:0.2288 ===
# train loss:2.227523450154595
# train loss:2.2309947951290807
# train loss:2.229127363727236
# === epoch:71, train acc:0.29333333333333333, test acc:0.2356 ===
# train loss:2.230206788188857
# train loss:2.22357844091613
# train loss:2.229759678308442
# === epoch:72, train acc:0.2833333333333333, test acc:0.2353 ===
# train loss:2.215424019600912
# train loss:2.244919417893437
# train loss:2.214720371058648
# === epoch:73, train acc:0.29333333333333333, test acc:0.241 ===
# train loss:2.221428784522763
# train loss:2.2205963991880235
# train loss:2.226973799782727
# === epoch:74, train acc:0.29, test acc:0.2405 ===
# train loss:2.230637955678037
# train loss:2.2556870907181135
# train loss:2.2262745354291518
# === epoch:75, train acc:0.30333333333333334, test acc:0.2488 ===
# train loss:2.2370463448740416
# train loss:2.206439773131499
# train loss:2.2237287028432506
# === epoch:76, train acc:0.31, test acc:0.2481 ===
# train loss:2.245085525175632
# train loss:2.217308312411047
# train loss:2.2272649795413555
# === epoch:77, train acc:0.31, test acc:0.2518 ===
# train loss:2.220270810282991
# train loss:2.2099317709963033
# train loss:2.2386722033476056
# === epoch:78, train acc:0.31, test acc:0.2537 ===
# train loss:2.215515994046173
# train loss:2.189807880045481
# train loss:2.1641321015641624
# === epoch:79, train acc:0.30666666666666664, test acc:0.2542 ===
# train loss:2.202221935055025
# train loss:2.243541996925934
# train loss:2.196379176326779
# === epoch:80, train acc:0.31, test acc:0.2565 ===
# train loss:2.2238123432092274
# train loss:2.226185155248375
# train loss:2.1704857829495925
# === epoch:81, train acc:0.31666666666666665, test acc:0.2596 ===
# train loss:2.1960882407229403
# train loss:2.216567629112806
# train loss:2.206842404001438
# === epoch:82, train acc:0.31333333333333335, test acc:0.2591 ===
# train loss:2.1849567079630514
# train loss:2.236522999700254
# train loss:2.170359739710687
# === epoch:83, train acc:0.31, test acc:0.2578 ===
# train loss:2.2278777949689794
# train loss:2.2181393438121138
# train loss:2.182657288261621
# === epoch:84, train acc:0.30666666666666664, test acc:0.2583 ===
# train loss:2.1937664888517077
# train loss:2.1961947646666835
# train loss:2.197338275315594
# === epoch:85, train acc:0.31333333333333335, test acc:0.2552 ===
# train loss:2.179061743910081
# train loss:2.216008308072937
# train loss:2.195589686113446
# === epoch:86, train acc:0.30333333333333334, test acc:0.2569 ===
# train loss:2.1983313127370905
# train loss:2.2023795424527277
# train loss:2.2217261811158076
# === epoch:87, train acc:0.30666666666666664, test acc:0.2566 ===
# train loss:2.224080289107326
# train loss:2.1933509786468144
# train loss:2.1921630502596146
# === epoch:88, train acc:0.31333333333333335, test acc:0.2618 ===
# train loss:2.180842885426579
# train loss:2.1946607018358546
# train loss:2.2060319011317238
# === epoch:89, train acc:0.32666666666666666, test acc:0.2673 ===
# train loss:2.1967099460827084
# train loss:2.1763826319609305
# train loss:2.1631715582951063
# === epoch:90, train acc:0.32, test acc:0.2703 ===
# train loss:2.1845757350520434
# train loss:2.1555376145762626
# train loss:2.166778781619849
# === epoch:91, train acc:0.32666666666666666, test acc:0.2719 ===
# train loss:2.2158836856709776
# train loss:2.1889877442614143
# train loss:2.1938427727335146
# === epoch:92, train acc:0.3333333333333333, test acc:0.2732 ===
# train loss:2.2039414336148972
# train loss:2.1818153542521586
# train loss:2.193433263441942
# === epoch:93, train acc:0.33, test acc:0.2727 ===
# train loss:2.1379423567856244
# train loss:2.2179256566003884
# train loss:2.1843510385767058
# === epoch:94, train acc:0.3433333333333333, test acc:0.2751 ===
# train loss:2.1660929503057234
# train loss:2.1859133094825025
# train loss:2.1844675011916723
# === epoch:95, train acc:0.3333333333333333, test acc:0.2736 ===
# train loss:2.1373965556109606
# train loss:2.1754165463006636
# train loss:2.164971279464208
# === epoch:96, train acc:0.31666666666666665, test acc:0.272 ===
# train loss:2.185233612910838
# train loss:2.20722489389318
# train loss:2.1828250912227456
# === epoch:97, train acc:0.32666666666666666, test acc:0.2743 ===
# train loss:2.224091950005855
# train loss:2.1587247905243663
# train loss:2.186129709406318
# === epoch:98, train acc:0.3233333333333333, test acc:0.2726 ===
# train loss:2.168290309432277
# train loss:2.1862631054796897
# train loss:2.180170577254764
# === epoch:99, train acc:0.32666666666666666, test acc:0.274 ===
# train loss:2.130820002477009
# train loss:2.1613282178064908
# train loss:2.209007182518148
# === epoch:100, train acc:0.3433333333333333, test acc:0.277 ===
# train loss:2.150333704876046
# train loss:2.2053261486311935
# train loss:2.1510462463322217
# === epoch:101, train acc:0.33666666666666667, test acc:0.2768 ===
# train loss:2.180866738057412
# train loss:2.1490375645050714
# train loss:2.096749436680187
# === epoch:102, train acc:0.3333333333333333, test acc:0.276 ===
# train loss:2.160482716644364
# train loss:2.143484656849004
# train loss:2.1625343209852494
# === epoch:103, train acc:0.3466666666666667, test acc:0.2769 ===
# train loss:2.1358629083698917
# train loss:2.119180609821326
# train loss:2.166094741112955
# === epoch:104, train acc:0.3333333333333333, test acc:0.2758 ===
# train loss:2.157413185030421
# train loss:2.139088686856718
# train loss:2.202753710125794
# === epoch:105, train acc:0.3433333333333333, test acc:0.2764 ===
# train loss:2.1737169850810334
# train loss:2.1601404233953074
# train loss:2.1787531418524786
# === epoch:106, train acc:0.3433333333333333, test acc:0.2765 ===
# train loss:2.126406796987314
# train loss:2.171844158130252
# train loss:2.1670805274855542
# === epoch:107, train acc:0.3466666666666667, test acc:0.2774 ===
# train loss:2.083764231041327
# train loss:2.1724836974022024
# train loss:2.1558885871465545
# === epoch:108, train acc:0.35, test acc:0.2774 ===
# train loss:2.0932367901267774
# train loss:2.183456138103363
# train loss:2.0984079197649295
# === epoch:109, train acc:0.35333333333333333, test acc:0.279 ===
# train loss:2.098494328068335
# train loss:2.145829413254229
# train loss:2.1204740937772706
# === epoch:110, train acc:0.3433333333333333, test acc:0.2782 ===
# train loss:2.1685089853867257
# train loss:2.102229149402538
# train loss:2.1120376827026885
# === epoch:111, train acc:0.3433333333333333, test acc:0.2795 ===
# train loss:2.133816701226672
# train loss:2.113817705099558
# train loss:2.145493176541782
# === epoch:112, train acc:0.3433333333333333, test acc:0.2789 ===
# train loss:2.1261460704430175
# train loss:2.138976076032209
# train loss:2.084008660138327
# === epoch:113, train acc:0.35, test acc:0.2818 ===
# train loss:2.111633683124452
# train loss:2.1267992952962955
# train loss:2.1098967539834432
# === epoch:114, train acc:0.35, test acc:0.2852 ===
# train loss:2.0341190711561143
# train loss:2.0929583241915104
# train loss:2.075881213451751
# === epoch:115, train acc:0.3466666666666667, test acc:0.2799 ===
# train loss:2.0928440557923538
# train loss:2.1545382721590274
# train loss:2.124117237821755
# === epoch:116, train acc:0.3466666666666667, test acc:0.2826 ===
# train loss:2.128938343303682
# train loss:2.1297650657846394
# train loss:2.0676046136674437
# === epoch:117, train acc:0.35, test acc:0.2852 ===
# train loss:2.1306998485906785
# train loss:2.1090072635227326
# train loss:2.094841051006126
# === epoch:118, train acc:0.3566666666666667, test acc:0.2846 ===
# train loss:2.1600424538152527
# train loss:2.1812979937538977
# train loss:2.102946617363991
# === epoch:119, train acc:0.3466666666666667, test acc:0.2854 ===
# train loss:2.1078891215388764
# train loss:2.071368877749914
# train loss:2.069198767735327
# === epoch:120, train acc:0.3566666666666667, test acc:0.2858 ===
# train loss:2.139188132398088
# train loss:2.148405329146629
# train loss:2.1386652192520423
# === epoch:121, train acc:0.3566666666666667, test acc:0.29 ===
# train loss:2.100544884712984
# train loss:2.0779613069238776
# train loss:2.1126615528212067
# === epoch:122, train acc:0.36333333333333334, test acc:0.2902 ===
# train loss:2.1105223413048524
# train loss:2.102710804757247
# train loss:2.071961800255607
# === epoch:123, train acc:0.36333333333333334, test acc:0.2907 ===
# train loss:2.095531370668255
# train loss:2.0416104562966892
# train loss:2.009958103955037
# === epoch:124, train acc:0.3566666666666667, test acc:0.2911 ===
# train loss:2.0497386269718625
# train loss:2.0884226173864073
# train loss:2.0263530035667605
# === epoch:125, train acc:0.36333333333333334, test acc:0.2908 ===
# train loss:2.1126653544288065
# train loss:2.1183124257623827
# train loss:1.9936347403376302
# === epoch:126, train acc:0.36333333333333334, test acc:0.2906 ===
# train loss:2.0853319108464534
# train loss:2.1513410001839013
# train loss:2.060991847956575
# === epoch:127, train acc:0.36666666666666664, test acc:0.295 ===
# train loss:1.9816536222432322
# train loss:2.096017171251716
# train loss:2.0646223863004676
# === epoch:128, train acc:0.36666666666666664, test acc:0.2944 ===
# train loss:2.128413377740109
# train loss:1.9717222601897728
# train loss:2.1117441350041095
# === epoch:129, train acc:0.37, test acc:0.2941 ===
# train loss:2.136392774292774
# train loss:2.083355864513958
# train loss:2.0864516636028423
# === epoch:130, train acc:0.37, test acc:0.2946 ===
# train loss:1.9604185035754886
# train loss:2.0714076211764088
# train loss:2.1093427412537333
# === epoch:131, train acc:0.37, test acc:0.2976 ===
# train loss:2.117238936383824
# train loss:2.0449787282040397
# train loss:1.974179573349326
# === epoch:132, train acc:0.36666666666666664, test acc:0.297 ===
# train loss:2.0254957149356154
# train loss:1.9899732293841075
# train loss:2.0275074024473296
# === epoch:133, train acc:0.36333333333333334, test acc:0.2959 ===
# train loss:1.9934413926226628
# train loss:2.0642358233981137
# train loss:2.008538827875027
# === epoch:134, train acc:0.36333333333333334, test acc:0.2948 ===
# train loss:2.104088000269959
# train loss:2.06370078151226
# train loss:1.999234460725015
# === epoch:135, train acc:0.36666666666666664, test acc:0.2968 ===
# train loss:2.0027034185483577
# train loss:1.9777386310984773
# train loss:2.0780956300582605
# === epoch:136, train acc:0.37, test acc:0.2954 ===
# train loss:2.062769652652558
# train loss:1.9886188055925382
# train loss:1.9500309275482182
# === epoch:137, train acc:0.37333333333333335, test acc:0.2966 ===
# train loss:1.9946672405191896
# train loss:1.984096281750758
# train loss:2.0447732206599327
# === epoch:138, train acc:0.37333333333333335, test acc:0.2961 ===
# train loss:2.0450766621148695
# train loss:1.9984022324897155
# train loss:2.033254251502725
# === epoch:139, train acc:0.37333333333333335, test acc:0.2997 ===
# train loss:1.9656835008026103
# train loss:2.0270139102682077
# train loss:2.012887201980769
# === epoch:140, train acc:0.38333333333333336, test acc:0.3023 ===
# train loss:2.0081358322260776
# train loss:1.9067781810823852
# train loss:2.0142405335564164
# === epoch:141, train acc:0.38666666666666666, test acc:0.3038 ===
# train loss:2.1302004102859136
# train loss:2.007389643471996
# train loss:1.9619097657947697
# === epoch:142, train acc:0.39, test acc:0.307 ===
# train loss:2.0325241990717586
# train loss:1.928781804013671
# train loss:2.0813123107025695
# === epoch:143, train acc:0.39666666666666667, test acc:0.3089 ===
# train loss:2.030160656350641
# train loss:2.085449233918388
# train loss:1.997700449460032
# === epoch:144, train acc:0.4, test acc:0.311 ===
# train loss:2.0077100012793028
# train loss:1.984554984570079
# train loss:1.9449234424462154
# === epoch:145, train acc:0.4, test acc:0.3116 ===
# train loss:1.9809818380380622
# train loss:1.9903438166430667
# train loss:1.9914381362820208
# === epoch:146, train acc:0.4033333333333333, test acc:0.3115 ===
# train loss:2.068889698657862
# train loss:1.9432109504489197
# train loss:1.9815976414201881
# === epoch:147, train acc:0.41, test acc:0.3116 ===
# train loss:2.0262196584758168
# train loss:1.8736566753084063
# train loss:2.0404813389157637
# === epoch:148, train acc:0.41333333333333333, test acc:0.3145 ===
# train loss:2.023843966985721
# train loss:1.9456547399571318
# train loss:1.8999835587085956
# === epoch:149, train acc:0.41, test acc:0.3136 ===
# train loss:1.901507413641631
# train loss:1.8953654830677977
# train loss:1.9270054119895232
# === epoch:150, train acc:0.4066666666666667, test acc:0.3137 ===
# train loss:1.8328971708655495
# train loss:1.8747717605187955
# train loss:1.9934206544137658
# === epoch:151, train acc:0.4066666666666667, test acc:0.3139 ===
# train loss:1.8844365002634242
# train loss:1.9437456617904083
# train loss:1.9406829742840483
# === epoch:152, train acc:0.4033333333333333, test acc:0.3137 ===
# train loss:1.9643087575733746
# train loss:1.9674924018310775
# train loss:1.8743798541105479
# === epoch:153, train acc:0.4066666666666667, test acc:0.3175 ===
# train loss:2.0506203419063804
# train loss:1.9945805943216073
# train loss:1.9348520783710041
# === epoch:154, train acc:0.4166666666666667, test acc:0.3209 ===
# train loss:1.9040179513963542
# train loss:1.833944818156768
# train loss:1.9595558678521696
# === epoch:155, train acc:0.42, test acc:0.3257 ===
# train loss:2.003408355401922
# train loss:1.974459737794603
# train loss:2.0050847543206007
# === epoch:156, train acc:0.42333333333333334, test acc:0.3286 ===
# train loss:1.902883148423535
# train loss:1.942279657772997
# train loss:1.9607610354864187
# === epoch:157, train acc:0.4266666666666667, test acc:0.3329 ===
# train loss:1.8869947249413423
# train loss:1.8944352984853245
# train loss:1.8990286853859286
# === epoch:158, train acc:0.43, test acc:0.3321 ===
# train loss:1.967820663246416
# train loss:1.9233712587105174
# train loss:1.8367852885304299
# === epoch:159, train acc:0.43666666666666665, test acc:0.3358 ===
# train loss:1.906013298832292
# train loss:1.9942282764714947
# train loss:1.8902151039297863
# === epoch:160, train acc:0.44, test acc:0.3402 ===
# train loss:1.9645847871726054
# train loss:1.9677901883147901
# train loss:1.9568143613624616
# === epoch:161, train acc:0.44, test acc:0.341 ===
# train loss:1.9458930840550197
# train loss:1.9382321358461716
# train loss:1.9760824112645907
# === epoch:162, train acc:0.44333333333333336, test acc:0.3439 ===
# train loss:1.8030441080293387
# train loss:1.9032091200587486
# train loss:1.86203342590108
# === epoch:163, train acc:0.44333333333333336, test acc:0.3461 ===
# train loss:1.9960903504938678
# train loss:1.7826752177833252
# train loss:1.9289358928447515
# === epoch:164, train acc:0.44, test acc:0.3489 ===
# train loss:1.6948528539908114
# train loss:1.8627282845030484
# train loss:1.8877398302769557
# === epoch:165, train acc:0.44333333333333336, test acc:0.347 ===
# train loss:1.9171310083863373
# train loss:1.9058196861143202
# train loss:1.9828112482710047
# === epoch:166, train acc:0.44333333333333336, test acc:0.3527 ===
# train loss:1.8433142174652657
# train loss:1.9569989067207283
# train loss:1.9275669439436396
# === epoch:167, train acc:0.43666666666666665, test acc:0.3554 ===
# train loss:1.8291282558261812
# train loss:1.8056005649710818
# train loss:1.9658362597732164
# === epoch:168, train acc:0.44333333333333336, test acc:0.3587 ===
# train loss:1.8612035898538752
# train loss:1.8816261356891097
# train loss:1.9224225140366025
# === epoch:169, train acc:0.44, test acc:0.3539 ===
# train loss:1.8567356067887202
# train loss:1.8011637046538564
# train loss:1.9070429699012208
# === epoch:170, train acc:0.44333333333333336, test acc:0.3615 ===
# train loss:1.918329408856038
# train loss:1.8388851884148247
# train loss:1.8988677182392744
# === epoch:171, train acc:0.44333333333333336, test acc:0.3642 ===
# train loss:2.013400806692668
# train loss:1.9085917515455464
# train loss:1.9610208738903399
# === epoch:172, train acc:0.45, test acc:0.3666 ===
# train loss:1.7967296269576525
# train loss:1.8438363142600165
# train loss:1.8465939178774473
# === epoch:173, train acc:0.4533333333333333, test acc:0.368 ===
# train loss:1.9254831889281092
# train loss:1.8957524117077644
# train loss:1.9464438669715574
# === epoch:174, train acc:0.46, test acc:0.37 ===
# train loss:1.9067811270054849
# train loss:1.9143448568038404
# train loss:1.8888828589033386
# === epoch:175, train acc:0.4666666666666667, test acc:0.379 ===
# train loss:1.7921821470111237
# train loss:1.8980665159757757
# train loss:1.7840398609467707
# === epoch:176, train acc:0.4666666666666667, test acc:0.3784 ===
# train loss:1.823861252774156
# train loss:1.806763914100938
# train loss:1.8551216465112828
# === epoch:177, train acc:0.47, test acc:0.3818 ===
# train loss:1.9868936911025201
# train loss:1.822685696844749
# train loss:1.8274177609767555
# === epoch:178, train acc:0.4766666666666667, test acc:0.3844 ===
# train loss:1.8231376413283034
# train loss:1.8226672376540105
# train loss:1.6783422936130754
# === epoch:179, train acc:0.4766666666666667, test acc:0.3836 ===
# train loss:1.9171055305592004
# train loss:1.8666732076686339
# train loss:1.7906428861649761
# === epoch:180, train acc:0.4766666666666667, test acc:0.3844 ===
# train loss:1.912861601887507
# train loss:1.8102011261576074
# train loss:1.7537463313986266
# === epoch:181, train acc:0.4766666666666667, test acc:0.3861 ===
# train loss:1.872704681191609
# train loss:1.7924350004055811
# train loss:1.7258244540179526
# === epoch:182, train acc:0.47333333333333333, test acc:0.387 ===
# train loss:1.8125879142457928
# train loss:1.750373413312981
# train loss:1.8350958554788717
# === epoch:183, train acc:0.4766666666666667, test acc:0.3878 ===
# train loss:1.938526211768331
# train loss:1.8102335347489256
# train loss:1.8348979462076045
# === epoch:184, train acc:0.48333333333333334, test acc:0.3937 ===
# train loss:1.8224638528670551
# train loss:1.7883996695547872
# train loss:1.8609865639103589
# === epoch:185, train acc:0.48333333333333334, test acc:0.3892 ===
# train loss:1.7175476141464572
# train loss:1.667284986920889
# train loss:1.7989451396969556
# === epoch:186, train acc:0.4866666666666667, test acc:0.3964 ===
# train loss:1.8573330669567931
# train loss:1.817226397840419
# train loss:1.8584970388915913
# === epoch:187, train acc:0.49, test acc:0.3999 ===
# train loss:1.8530476479555649
# train loss:1.872442772717864
# train loss:1.7009618615613658
# === epoch:188, train acc:0.49333333333333335, test acc:0.4008 ===
# train loss:1.7053103123173414
# train loss:1.7057495614402214
# train loss:1.7322799379357532
# === epoch:189, train acc:0.5033333333333333, test acc:0.4032 ===
# train loss:1.8282195885220995
# train loss:1.7644865184316263
# train loss:1.9423061928800143
# === epoch:190, train acc:0.5233333333333333, test acc:0.4087 ===
# train loss:1.8399271506302273
# train loss:1.8095743719390365
# train loss:1.7218971044170368
# === epoch:191, train acc:0.5233333333333333, test acc:0.4121 ===
# train loss:1.8388358990290206
# train loss:1.804902893337202
# train loss:1.7023657652377486
# === epoch:192, train acc:0.5233333333333333, test acc:0.4155 ===
# train loss:1.7432682164575382
# train loss:1.7899614372079835
# train loss:1.76260148699545
# === epoch:193, train acc:0.52, test acc:0.4165 ===
# train loss:1.7703433391477048
# train loss:1.7739945408075684
# train loss:1.7531372998011472
# === epoch:194, train acc:0.5266666666666666, test acc:0.4204 ===
# train loss:1.938123173962129
# train loss:1.7761064455533573
# train loss:1.7912760284751874
# === epoch:195, train acc:0.54, test acc:0.4225 ===
# train loss:1.8350008173879329
# train loss:1.695125865095541
# train loss:1.7614021249276524
# === epoch:196, train acc:0.54, test acc:0.4224 ===
# train loss:1.8860788868176634
# train loss:1.6628187661012035
# train loss:1.796114439950875
# === epoch:197, train acc:0.54, test acc:0.4224 ===
# train loss:1.7790807232160912
# train loss:1.7253487032835446
# train loss:1.8364122939976593
# === epoch:198, train acc:0.5433333333333333, test acc:0.4275 ===
# train loss:1.7097408713365256
# train loss:1.7156431862081754
# train loss:1.7307522793483485
# === epoch:199, train acc:0.54, test acc:0.4276 ===
# train loss:1.646129946713269
# train loss:1.7237239217618887
# train loss:1.591586439440048
# === epoch:200, train acc:0.5366666666666666, test acc:0.425 ===
# train loss:1.7367924627523161
# train loss:1.6701572216684468
# train loss:1.6765907509921398
# === epoch:201, train acc:0.54, test acc:0.4285 ===
# train loss:1.6699727378807123
# train loss:1.6735308728906297
# train loss:1.61987306712551
# === epoch:202, train acc:0.5333333333333333, test acc:0.4257 ===
# train loss:1.6560634007416641
# train loss:1.819199304993583
# train loss:1.7456238338442558
# === epoch:203, train acc:0.54, test acc:0.4324 ===
# train loss:1.6658698490731307
# train loss:1.6499965066782545
# train loss:1.6535358484089622
# === epoch:204, train acc:0.5366666666666666, test acc:0.4341 ===
# train loss:1.7818236088779538
# train loss:1.6641565466669972
# train loss:1.6830701140229116
# === epoch:205, train acc:0.5433333333333333, test acc:0.4358 ===
# train loss:1.6812295957794967
# train loss:1.6529586263523826
# train loss:1.846294181071991
# === epoch:206, train acc:0.5466666666666666, test acc:0.4376 ===
# train loss:1.8254826891473956
# train loss:1.5446359920279793
# train loss:1.8711211885669823
# === epoch:207, train acc:0.5433333333333333, test acc:0.4372 ===
# train loss:1.743447706016771
# train loss:1.8154556667658586
# train loss:1.7765679283052254
# === epoch:208, train acc:0.5466666666666666, test acc:0.4383 ===
# train loss:1.731479587021532
# train loss:1.763156548728746
# train loss:1.6312545569330874
# === epoch:209, train acc:0.54, test acc:0.4398 ===
# train loss:1.8009659469204455
# train loss:1.708083342666462
# train loss:1.8408405921873583
# === epoch:210, train acc:0.55, test acc:0.4438 ===
# train loss:1.650418266334522
# train loss:1.6602761052367325
# train loss:1.6517976034622928
# === epoch:211, train acc:0.5466666666666666, test acc:0.4461 ===
# train loss:1.6766132896692898
# train loss:1.7686548981061747
# train loss:1.687680212582393
# === epoch:212, train acc:0.55, test acc:0.4486 ===
# train loss:1.6840548114726364
# train loss:1.6566890511869672
# train loss:1.641233514415306
# === epoch:213, train acc:0.56, test acc:0.447 ===
# train loss:1.6318110967574295
# train loss:1.670523171392979
# train loss:1.6650134465028925
# === epoch:214, train acc:0.5533333333333333, test acc:0.4478 ===
# train loss:1.6062440647505938
# train loss:1.637954125466118
# train loss:1.6397777911031455
# === epoch:215, train acc:0.56, test acc:0.4506 ===
# train loss:1.5509481814750188
# train loss:1.651829707498153
# train loss:1.6475712760394137
# === epoch:216, train acc:0.56, test acc:0.4493 ===
# train loss:1.6142921604988125
# train loss:1.6849715140895307
# train loss:1.6775894402536846
# === epoch:217, train acc:0.5666666666666667, test acc:0.451 ===
# train loss:1.790535786495045
# train loss:1.5785049085717622
# train loss:1.59698714282397
# === epoch:218, train acc:0.5666666666666667, test acc:0.4542 ===
# train loss:1.692326762895803
# train loss:1.5325316508046314
# train loss:1.7088273206108804
# === epoch:219, train acc:0.57, test acc:0.4582 ===
# train loss:1.739928270446169
# train loss:1.6468951794629132
# train loss:1.6992936463228845
# === epoch:220, train acc:0.5733333333333334, test acc:0.4632 ===
# train loss:1.6929882005148031
# train loss:1.658882958922272
# train loss:1.6006549680084874
# === epoch:221, train acc:0.5733333333333334, test acc:0.4631 ===
# train loss:1.5110738931397762
# train loss:1.4909485930455866
# train loss:1.585744910946636
# === epoch:222, train acc:0.57, test acc:0.4626 ===
# train loss:1.736635877260334
# train loss:1.6678382889307286
# train loss:1.4472387332973298
# === epoch:223, train acc:0.5666666666666667, test acc:0.4616 ===
# train loss:1.6583070373393272
# train loss:1.5829095858747784
# train loss:1.5673918481408047
# === epoch:224, train acc:0.5733333333333334, test acc:0.4612 ===
# train loss:1.5558081143377274
# train loss:1.6565690362256311
# train loss:1.6891645406795393
# === epoch:225, train acc:0.5733333333333334, test acc:0.464 ===
# train loss:1.606489568413369
# train loss:1.530313532020544
# train loss:1.6023505508866733
# === epoch:226, train acc:0.57, test acc:0.463 ===
# train loss:1.5636674967402657
# train loss:1.5846488660941456
# train loss:1.3854992980172849
# === epoch:227, train acc:0.5633333333333334, test acc:0.4632 ===
# train loss:1.6062860662215013
# train loss:1.4286225082105846
# train loss:1.501311756319138
# === epoch:228, train acc:0.5666666666666667, test acc:0.4633 ===
# train loss:1.592614530357051
# train loss:1.5550035534879063
# train loss:1.7108193208451226
# === epoch:229, train acc:0.5766666666666667, test acc:0.47 ===
# train loss:1.6041162035316512
# train loss:1.5134887427424348
# train loss:1.5806806878450725
# === epoch:230, train acc:0.5733333333333334, test acc:0.4713 ===
# train loss:1.5496858406728589
# train loss:1.6820324372380633
# train loss:1.4910887620917177
# === epoch:231, train acc:0.5733333333333334, test acc:0.4688 ===
# train loss:1.6363101405919331
# train loss:1.6285202632380325
# train loss:1.5508674262118847
# === epoch:232, train acc:0.5866666666666667, test acc:0.4765 ===
# train loss:1.4604053592538855
# train loss:1.4983886021453743
# train loss:1.5946870024630255
# === epoch:233, train acc:0.5866666666666667, test acc:0.4749 ===
# train loss:1.5735194770944891
# train loss:1.6320670306021483
# train loss:1.5264460846398396
# === epoch:234, train acc:0.5966666666666667, test acc:0.4791 ===
# train loss:1.426319881719083
# train loss:1.40718409509313
# train loss:1.430224932345122
# === epoch:235, train acc:0.5833333333333334, test acc:0.4777 ===
# train loss:1.4780000704232494
# train loss:1.4528891415897882
# train loss:1.469715043180174
# === epoch:236, train acc:0.58, test acc:0.4797 ===
# train loss:1.5762430259271747
# train loss:1.5960624504464789
# train loss:1.500760068554717
# === epoch:237, train acc:0.5833333333333334, test acc:0.4805 ===
# train loss:1.5056781872053597
# train loss:1.487315703152326
# train loss:1.5199429427957751
# === epoch:238, train acc:0.5833333333333334, test acc:0.4794 ===
# train loss:1.4503540585908163
# train loss:1.5321524762028316
# train loss:1.5705636557604772
# === epoch:239, train acc:0.5833333333333334, test acc:0.4795 ===
# train loss:1.5131587300863891
# train loss:1.4957356673441884
# train loss:1.5104822953514303
# === epoch:240, train acc:0.5866666666666667, test acc:0.481 ===
# train loss:1.4749425435106582
# train loss:1.5381816175672736
# train loss:1.4890536232329772
# === epoch:241, train acc:0.5933333333333334, test acc:0.4802 ===
# train loss:1.528210897472129
# train loss:1.5110663929168715
# train loss:1.3509327577839971
# === epoch:242, train acc:0.5933333333333334, test acc:0.4827 ===
# train loss:1.397535423557499
# train loss:1.3731645105590886
# train loss:1.5631139911846095
# === epoch:243, train acc:0.5966666666666667, test acc:0.4842 ===
# train loss:1.4797013381646968
# train loss:1.516414942797077
# train loss:1.2989538349897825
# === epoch:244, train acc:0.5966666666666667, test acc:0.4862 ===
# train loss:1.4169013232105088
# train loss:1.4996225210683114
# train loss:1.514569970734417
# === epoch:245, train acc:0.5966666666666667, test acc:0.4894 ===
# train loss:1.5533380969071298
# train loss:1.5935567097025762
# train loss:1.5723577608364026
# === epoch:246, train acc:0.6, test acc:0.4927 ===
# train loss:1.3947988818713457
# train loss:1.4547346136315098
# train loss:1.4326598746585275
# === epoch:247, train acc:0.6033333333333334, test acc:0.4949 ===
# train loss:1.4683600608523637
# train loss:1.4359871997069817
# train loss:1.457309832410258
# === epoch:248, train acc:0.6066666666666667, test acc:0.4939 ===
# train loss:1.3998612131323285
# train loss:1.4812774981671157
# train loss:1.4718281697786946
# === epoch:249, train acc:0.6, test acc:0.4942 ===
# train loss:1.5088947615315538
# train loss:1.4286029099024313
# train loss:1.4811267286234584
# === epoch:250, train acc:0.6, test acc:0.4946 ===
# train loss:1.2746405022134433
# train loss:1.4006095125589175
# train loss:1.4738999579422247
# === epoch:251, train acc:0.6066666666666667, test acc:0.4924 ===
# train loss:1.4194751595736121
# train loss:1.5487134581498365
# train loss:1.3488024529288956
# === epoch:252, train acc:0.6, test acc:0.4927 ===
# train loss:1.4645065881537196
# train loss:1.3536087977747917
# train loss:1.4113360986639385
# === epoch:253, train acc:0.6, test acc:0.4928 ===
# train loss:1.4050865820112868
# train loss:1.5966981606750932
# train loss:1.3071236336572096
# === epoch:254, train acc:0.6033333333333334, test acc:0.4961 ===
# train loss:1.3264621014410927
# train loss:1.3146098005781752
# train loss:1.4359213315069246
# === epoch:255, train acc:0.6, test acc:0.4958 ===
# train loss:1.4960303584072698
# train loss:1.384978385388691
# train loss:1.3600433637805844
# === epoch:256, train acc:0.6, test acc:0.4967 ===
# train loss:1.4076770118510158
# train loss:1.3984541611422678
# train loss:1.287741719686845
# === epoch:257, train acc:0.6, test acc:0.497 ===
# train loss:1.2953633467227263
# train loss:1.303320478813572
# train loss:1.4781834711016515
# === epoch:258, train acc:0.6066666666666667, test acc:0.4958 ===
# train loss:1.2263667828639822
# train loss:1.331783371123661
# train loss:1.3220043554519574
# === epoch:259, train acc:0.6033333333333334, test acc:0.4957 ===
# train loss:1.290133643965591
# train loss:1.5453431225010261
# train loss:1.3804152748829401
# === epoch:260, train acc:0.6033333333333334, test acc:0.4985 ===
# train loss:1.4031443175069904
# train loss:1.4170069708208919
# train loss:1.4490331322879595
# === epoch:261, train acc:0.6066666666666667, test acc:0.5006 ===
# train loss:1.3026201325823785
# train loss:1.2890053114060336
# train loss:1.2694700076658694
# === epoch:262, train acc:0.6033333333333334, test acc:0.5015 ===
# train loss:1.346196049660255
# train loss:1.4288531374967886
# train loss:1.330822268722102
# === epoch:263, train acc:0.6066666666666667, test acc:0.504 ===
# train loss:1.3409234643836356
# train loss:1.4157070951249056
# train loss:1.3497423745862067
# === epoch:264, train acc:0.6066666666666667, test acc:0.5027 ===
# train loss:1.3649632531347686
# train loss:1.414901613906475
# train loss:1.2876089629914602
# === epoch:265, train acc:0.6066666666666667, test acc:0.5057 ===
# train loss:1.1889152207114329
# train loss:1.314519788115018
# train loss:1.3499699744771607
# === epoch:266, train acc:0.6066666666666667, test acc:0.5072 ===
# train loss:1.2190396518223856
# train loss:1.3151033415594588
# train loss:1.2545306823014097
# === epoch:267, train acc:0.61, test acc:0.5084 ===
# train loss:1.2892264347158011
# train loss:1.2678551205021427
# train loss:1.1439618290067335
# === epoch:268, train acc:0.6166666666666667, test acc:0.5085 ===
# train loss:1.2509522353662448
# train loss:1.303437101876908
# train loss:1.2846616583573516
# === epoch:269, train acc:0.62, test acc:0.5083 ===
# train loss:1.3298994791282888
# train loss:1.253743493960466
# train loss:1.3237745138323769
# === epoch:270, train acc:0.6233333333333333, test acc:0.5102 ===
# train loss:1.2416468247684815
# train loss:1.2463881366173848
# train loss:1.3781149496508727
# === epoch:271, train acc:0.6266666666666667, test acc:0.5125 ===
# train loss:1.2493667312357761
# train loss:1.2410636053911883
# train loss:1.230047490331116
# === epoch:272, train acc:0.6266666666666667, test acc:0.5138 ===
# train loss:1.2637794036329242
# train loss:1.2724442834593201
# train loss:1.239980100080563
# === epoch:273, train acc:0.62, test acc:0.5148 ===
# train loss:1.2064143046985183
# train loss:1.1797664985321208
# train loss:1.2378207459138155
# === epoch:274, train acc:0.6166666666666667, test acc:0.517 ===
# train loss:1.204128688920656
# train loss:1.1990453320057233
# train loss:1.1661759757665866
# === epoch:275, train acc:0.6166666666666667, test acc:0.5154 ===
# train loss:1.1307259538924217
# train loss:1.1770985653762331
# train loss:1.221547156001498
# === epoch:276, train acc:0.62, test acc:0.5136 ===
# train loss:1.299975276373374
# train loss:1.178948672254473
# train loss:1.2977679779796665
# === epoch:277, train acc:0.6166666666666667, test acc:0.5163 ===
# train loss:1.2101992903738614
# train loss:1.2768847930847087
# train loss:1.3062498403550566
# === epoch:278, train acc:0.63, test acc:0.5195 ===
# train loss:1.2301417388910536
# train loss:1.2422010332052644
# train loss:1.326728289800496
# === epoch:279, train acc:0.63, test acc:0.5217 ===
# train loss:1.2104213520838425
# train loss:1.1533182421800772
# train loss:1.2356697398125407
# === epoch:280, train acc:0.6366666666666667, test acc:0.5214 ===
# train loss:1.1736947381270424
# train loss:1.3249908767918814
# train loss:1.2218401858000218
# === epoch:281, train acc:0.64, test acc:0.5265 ===
# train loss:1.2076019570864402
# train loss:1.1909718926354251
# train loss:1.449689200224935
# === epoch:282, train acc:0.64, test acc:0.5275 ===
# train loss:1.213124852096091
# train loss:1.1059423723513715
# train loss:1.319438394382803
# === epoch:283, train acc:0.64, test acc:0.5275 ===
# train loss:1.2805647947059637
# train loss:1.0564428134031538
# train loss:1.2228760183742293
# === epoch:284, train acc:0.64, test acc:0.5256 ===
# train loss:1.158406329218337
# train loss:1.25191277153659
# train loss:1.1916648577086653
# === epoch:285, train acc:0.64, test acc:0.5306 ===
# train loss:1.2035702899267542
# train loss:1.2706654693103854
# train loss:1.1805030302990005
# === epoch:286, train acc:0.65, test acc:0.5311 ===
# train loss:1.122247153372467
# train loss:1.1137458937284854
# train loss:1.1499136427579304
# === epoch:287, train acc:0.64, test acc:0.5316 ===
# train loss:1.1373395130752875
# train loss:1.0939234074399453
# train loss:1.1876827622616017
# === epoch:288, train acc:0.64, test acc:0.5302 ===
# train loss:1.2270832758067876
# train loss:1.1959314933598824
# train loss:1.1819513225473142
# === epoch:289, train acc:0.64, test acc:0.5294 ===
# train loss:1.1649428210445716
# train loss:1.1184557805110682
# train loss:1.2151350120578739
# === epoch:290, train acc:0.65, test acc:0.5306 ===
# train loss:1.2149120077970745
# train loss:1.1786621563617365
# train loss:1.2038493913547883
# === epoch:291, train acc:0.6433333333333333, test acc:0.5326 ===
# train loss:1.2069888129346282
# train loss:1.029187580202818
# train loss:1.0794125675165267
# === epoch:292, train acc:0.6466666666666666, test acc:0.5366 ===
# train loss:1.214372569286099
# train loss:1.0798507150944012
# train loss:1.0843856015515143
# === epoch:293, train acc:0.6466666666666666, test acc:0.5394 ===
# train loss:1.1323864242231922
# train loss:1.067510027584936
# train loss:1.075202006027561
# === epoch:294, train acc:0.6466666666666666, test acc:0.5402 ===
# train loss:1.0588848237266568
# train loss:0.9681022050374761
# train loss:1.0664590911223333
# === epoch:295, train acc:0.6466666666666666, test acc:0.5395 ===
# train loss:1.2308790839196124
# train loss:1.115447597888691
# train loss:1.2275717411464317
# === epoch:296, train acc:0.6466666666666666, test acc:0.5401 ===
# train loss:1.119555051166532
# train loss:1.2017387674385
# train loss:1.0663283177981606
# === epoch:297, train acc:0.6533333333333333, test acc:0.5413 ===
# train loss:1.1149681887492906
# train loss:1.0421053954843642
# train loss:1.1501940219650713
# === epoch:298, train acc:0.6566666666666666, test acc:0.5422 ===
# train loss:1.180029131825279
# train loss:1.1097692768052865
# train loss:1.026278607637527
# === epoch:299, train acc:0.6566666666666666, test acc:0.5424 ===
# train loss:0.998493309087991
# train loss:1.0249915207093345
# train loss:1.1168362076467278
# === epoch:300, train acc:0.6566666666666666, test acc:0.5415 ===
# train loss:0.9769301200448344
# train loss:1.0216324590705361
# train loss:1.139532448150427
# === epoch:301, train acc:0.6566666666666666, test acc:0.5405 ===
# train loss:1.0250820037334312
# train loss:1.0090185512929755
# =============== Final Test Accuracy ===============
# test acc:0.5401
